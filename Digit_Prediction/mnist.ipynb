# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
# %matplotlib inline

np.random.seed(2)

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import itertools

from keras.utils.np_utils import to_categorical # convert to one-hot-encoding
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.optimizers import RMSprop
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Using TensorFlow backend.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ed486fdf-a001-4a50-9b9f-91f7d85bb95e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ed486fdf-a001-4a50-9b9f-91f7d85bb95e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.csv to test.csv
# Saving train.csv to train.csv

# %%
import io
import pandas as pd
df2 = pd.read_csv(io.BytesIO(uploaded['train.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
import pandas as pd
df1 = pd.read_csv(io.BytesIO(uploaded['test.csv']))

# %%
test = df1
del df1

# %%
df=df2

# %%
ytrain = df2['label']
xtrain = df2.drop('label',axis = 1)

# %%
del df2

# %%
xtrain = xtrain/255.0
test = test/255.0

# %%
xtrain = xtrain.values.reshape(-1,28,28,1)
test = test.values.reshape(-1,28,28,1)

# %%
ytrain = to_categorical(ytrain,num_classes=10)

# %%
xtr,xte,ytr,yte = train_test_split(xtrain,ytrain,test_size = 0.1)

# %%
model = Sequential()

# %%
from keras.layers import BatchNormalization

# %%
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',activation ='relu', input_shape = (28,28,1)))
model.add(BatchNormalization())
model.add(Conv2D(filters=32 , kernel_size = (5,5), padding='Same' , activation='relu' , input_shape = (28,28,1)))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# %%
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same',activation ='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=64 , kernel_size = (5,5), padding='Same' , activation='relu' ))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2) , strides=(2,2)))
model.add(Dropout(0.2))

# %%
model.add(Flatten())
model.add(Dense(256, activation = "relu"))
model.add(Dropout(0.2))
model.add(Dense(10, activation = "softmax"))

# %%
optimizer = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)

# %%
batch =

# %%
model.compile(optimizer = optimizer , loss = "categorical_crossentropy", metrics=["accuracy"])

# %%
history = model.fit(xtr, ytr, batch_size = 86, epochs = 30 , validation_data = (xte, yte), verbose = 2)
# Out:
# Train on 37800 samples, validate on 4200 samples
# Epoch 1/30
#  - 552s - loss: 0.2174 - accuracy: 0.9397 - val_loss: 0.0648 - val_accuracy: 0.9805
# Epoch 2/30
#  - 554s - loss: 0.0898 - accuracy: 0.9790 - val_loss: 0.0671 - val_accuracy: 0.9838
# Epoch 3/30
#  - 555s - loss: 0.0681 - accuracy: 0.9840 - val_loss: 0.0826 - val_accuracy: 0.9817
# Epoch 4/30
#  - 554s - loss: 0.0582 - accuracy: 0.9865 - val_loss: 0.1325 - val_accuracy: 0.9745
# Epoch 5/30
#  - 552s - loss: 0.0521 - accuracy: 0.9882 - val_loss: 0.0762 - val_accuracy: 0.9881
# Epoch 6/30
#  - 556s - loss: 0.0425 - accuracy: 0.9904 - val_loss: 0.0468 - val_accuracy: 0.9914
# Epoch 7/30
#  - 554s - loss: 0.0344 - accuracy: 0.9925 - val_loss: 0.0828 - val_accuracy: 0.9890
# Epoch 8/30
#  - 552s - loss: 0.0353 - accuracy: 0.9925 - val_loss: 0.0627 - val_accuracy: 0.9895
# Epoch 9/30
#  - 552s - loss: 0.0314 - accuracy: 0.9931 - val_loss: 0.0625 - val_accuracy: 0.9888
# Epoch 10/30
#  - 550s - loss: 0.0280 - accuracy: 0.9942 - val_loss: 0.0564 - val_accuracy: 0.9910
# Epoch 11/30
#  - 556s - loss: 0.0260 - accuracy: 0.9941 - val_loss: 0.0690 - val_accuracy: 0.9910
# Epoch 12/30
#  - 557s - loss: 0.0243 - accuracy: 0.9948 - val_loss: 0.0586 - val_accuracy: 0.9931
# Epoch 13/30
#  - 556s - loss: 0.0191 - accuracy: 0.9954 - val_loss: 0.0442 - val_accuracy: 0.9917
# Epoch 14/30
#  - 551s - loss: 0.0205 - accuracy: 0.9957 - val_loss: 0.0630 - val_accuracy: 0.9919
# Epoch 15/30
#  - 549s - loss: 0.0161 - accuracy: 0.9963 - val_loss: 0.0495 - val_accuracy: 0.9921
# Epoch 16/30
#  - 550s - loss: 0.0176 - accuracy: 0.9962 - val_loss: 0.0442 - val_accuracy: 0.9933
# Epoch 17/30
#  - 551s - loss: 0.0132 - accuracy: 0.9970 - val_loss: 0.0473 - val_accuracy: 0.9929
# Epoch 18/30
#  - 553s - loss: 0.0124 - accuracy: 0.9968 - val_loss: 0.0604 - val_accuracy: 0.9929
# Epoch 19/30
#  - 550s - loss: 0.0119 - accuracy: 0.9969 - val_loss: 0.0663 - val_accuracy: 0.9921
# Epoch 20/30
#  - 549s - loss: 0.0143 - accuracy: 0.9966 - val_loss: 0.0689 - val_accuracy: 0.9905
# Epoch 21/30
#  - 545s - loss: 0.0125 - accuracy: 0.9970 - val_loss: 0.0895 - val_accuracy: 0.9900
# Epoch 22/30
#  - 541s - loss: 0.0109 - accuracy: 0.9973 - val_loss: 0.0616 - val_accuracy: 0.9943
# Epoch 23/30
#  - 542s - loss: 0.0093 - accuracy: 0.9980 - val_loss: 0.0719 - val_accuracy: 0.9940
# Epoch 24/30
#  - 542s - loss: 0.0115 - accuracy: 0.9974 - val_loss: 0.0676 - val_accuracy: 0.9924
# Epoch 25/30
#  - 544s - loss: 0.0100 - accuracy: 0.9978 - val_loss: 0.0682 - val_accuracy: 0.9936
# Epoch 26/30
#  - 544s - loss: 0.0083 - accuracy: 0.9982 - val_loss: 0.0641 - val_accuracy: 0.9917
# Epoch 27/30
#  - 544s - loss: 0.0077 - accuracy: 0.9981 - val_loss: 0.0724 - val_accuracy: 0.9926
# Epoch 28/30
#  - 544s - loss: 0.0085 - accuracy: 0.9981 - val_loss: 0.0644 - val_accuracy: 0.9926
# Epoch 29/30
#  - 544s - loss: 0.0074 - accuracy: 0.9986 - val_loss: 0.0640 - val_accuracy: 0.9933
# Epoch 30/30
#  - 546s - loss: 0.0073 - accuracy: 0.9983 - val_loss: 0.0520 - val_accuracy: 0.9948

# %%
results = model.predict(test)

# %%
results = np.argmax(results,axis = 1)
results = pd.Series(results,name="Label")

# %%
submission = pd.concat([pd.Series(range(1,28001),name = "ImageId"),results],axis = 1)
submission.to_csv("cnnmnist2.csv",index=False)

# %%
files.download('cnnmnist2.csv')

# %%
from google.colab import files
# !ls
 
# !rm sample_data
# Out:
# sample_data
# rm: cannot remove 'sample_data': Is a directory
